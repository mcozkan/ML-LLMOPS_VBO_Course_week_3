# %% [markdown]
# #### Lib Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Data Load & Profilling

# %%
df = pd.read_csv("../data/raw/housing.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.describe().T
# Out:
#                       count           mean            std         min  \
# longitude           20640.0    -119.569704       2.003532   -124.3500
# latitude            20640.0      35.631861       2.135952     32.5400
# housing_median_age  20640.0      28.639486      12.585558      1.0000
# total_rooms         20640.0    2635.763081    2181.615252      2.0000
# total_bedrooms      20433.0     537.870553     421.385070      1.0000
# population          20640.0    1425.476744    1132.462122      3.0000
# households          20640.0     499.539680     382.329753      1.0000
# median_income       20640.0       3.870671       1.899822      0.4999
# median_house_value  20640.0  206855.816909  115395.615874  14999.0000
#
#                             25%          50%           75%          max
# longitude             -121.8000    -118.4900    -118.01000    -114.3100
# latitude                33.9300      34.2600      37.71000      41.9500
# ...

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# I would like to understand if the null values mean they are studio flats...
df["rooms_per_household"] = df["total_rooms"] / df["households"]

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    rooms_per_household
# 0             6.984127
# ...

# %%
df[df["total_bedrooms"].isnull()].head()
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290    -122.16     37.77                47.0       1256.0             NaN
# 341    -122.17     37.75                38.0        992.0             NaN
# 538    -122.28     37.78                29.0       5154.0             NaN
# 563    -122.24     37.75                45.0        891.0             NaN
# 696    -122.10     37.69                41.0        746.0             NaN
#
#      population  households  median_income  median_house_value  \
# 290       570.0       218.0         4.3750            161900.0
# 341       732.0       259.0         1.6196             85100.0
# 538      3741.0      1273.0         2.5762            173400.0
# 563       384.0       146.0         4.9489            247100.0
# 696       387.0       161.0         3.9063            178400.0
#
#     ocean_proximity  rooms_per_household
# 290        NEAR BAY             5.761468
# 341        NEAR BAY             3.830116
# ...

# %%
df[df["total_bedrooms"].isnull()].tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
#        population  households  median_income  median_house_value  \
# 20267      3171.0       779.0         3.3409            220500.0
# 20268      1938.0       762.0         1.6953            167400.0
# 20372      1701.0       669.0         5.1033            410700.0
# 20460      2734.0       814.0         6.6073            258100.0
# 20484      1705.0       495.0         5.7376            218600.0
#
#       ocean_proximity  rooms_per_household
# 20267      NEAR OCEAN             4.646983
# ...

# %%
df["ocean_proximity"].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
mapping = {
    'INLAND': 0,
    '<1H OCEAN': 1,
    'NEAR OCEAN': 2,
    'NEAR BAY': 3,
    'ISLAND': 4
}
df["ocean_proximity_c"] = df["ocean_proximity"].map(mapping)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    rooms_per_household  ocean_proximity_c
# ...

# %%
df["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
df_num = df.select_dtypes(include=["number"])
df_num.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    rooms_per_household  ocean_proximity_c
# 0             6.984127                  3
# 1             6.238137                  3
# ...

# %% [markdown]
# #### Data Visualization

# %%
def histoplot(dataframe):
    for col in dataframe.columns:
        sns.histplot(data = dataframe, x = col,  kde = True, color = "teal", bins = 50)
        plt.show()

# %%
histoplot(df_num)

# %%
df.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
        s=df["population"]/100, label="nüfus", figsize=(10,7),
        c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True)

plt.title("Konut Fiyatları ve Lokasyon İlişkisi")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_num.corr(), annot = True, cmap="RdYlBu", fmt=".2f")
plt.show()

# %%
df.isnull().sum()
# Out:
# longitude                0
# latitude                 0
# housing_median_age       0
# total_rooms              0
# total_bedrooms         207
# population               0
# households               0
# median_income            0
# median_house_value       0
# ocean_proximity          0
# rooms_per_household      0
# ocean_proximity_c        0
# dtype: int64

# %% [markdown]
# #### Threshold Check

# %%
def catch_threshold(dataframe, col):
    q1 = dataframe[col].quantile(0.25)
    q3 = dataframe[col].quantile(0.75)
    iqr = q3 - q1

    #boundires detection:
    low_bond = q1 - iqr * 1.5
    up_bond = q3 + iqr * 1.5
    
    return low_bond, up_bond

# %%
def show_th(dataframe, cols):
    for col in cols:
        low, up = catch_threshold(dataframe, col)
        outliers = dataframe[(dataframe[col]< low )| (dataframe[col] > up)]
        if len(outliers) > 0:
            print(f"{col} için {len(outliers)} threshold found....")

# %%
num_cols = df.select_dtypes(include=["number"]).columns

# %%
show_th(df, num_cols)
# Out:
# total_rooms için 1287 threshold found....
# total_bedrooms için 1271 threshold found....
# population için 1196 threshold found....
# households için 1220 threshold found....
# median_income için 681 threshold found....
# median_house_value için 1071 threshold found....
# rooms_per_household için 511 threshold found....
# ocean_proximity_c için 2295 threshold found....

# %%
#plt.figure(figsize=(ax, bx))

plt.boxplot(df["total_rooms"])
plt.show()

# %%
print(1287 / df["total_rooms"].count() * 100)
# Out:
# 6.2354651162790695

# %%
for col in num_cols:
    plt.boxplot(df[col])
    plt.title(col)
    plt.show()
